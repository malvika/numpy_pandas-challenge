# %%
#Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#import json into data frame
purchase_data_df = pd.read_json("purchase_data.json")
purchase_data_df.head()
# Out:
#    Age Gender  Item ID                                  Item Name  Price  \
# 0   38   Male      165                Bone Crushing Silver Skewer   3.37
# 1   21   Male      119  Stormbringer, Dark Blade of Ending Misery   2.32
# 2   34   Male      174                            Primitive Blade   2.46
# 3   21   Male       92                               Final Critic   1.36
# 4   23   Male       63                             Stormfury Mace   1.27
#
#              SN
# 0     Aelalis34
# 1        Eolo46
# 2   Assastnya25
# 3  Pheusrical25
# 4        Aela59

# %%
#Player Count: Count the total number of players by grouping the unique SN's
players_df = purchase_data_df.groupby("SN")["SN"].nunique()
number_of_players = players_df.count() 
number_of_players
# Out:
# 573

# %%
players_df = pd.DataFrame([{ "Number of Players": number_of_players}])
players_df
# Out:
#    Number of Players
# 0                573

# %%
#Purchasing Analysis (Total)

#Number of Unique Items
dropping_duplicates = purchase_data_df.drop_duplicates(['Item ID'], keep = 'last')

#counts items by unique ID
total_unique = len(dropping_duplicates)
total_unique
# Out:
# 183

# %%
#Average Purchase Price
average_price_df = purchase_data_df ["Price"].mean()
round(average_price_df, 2)
# Out:
# 2.93

# %%
#Total Number of Purchases
total_purchases_df = purchase_data_df["Price"].count()
total_purchases_df
# Out:
# 780

# %%
#Total Revenue
total_revenue_df = purchase_data_df["Price"].sum()
round(total_revenue_df, 2)
# Out:
# 2286.33

# %%
purchasing_analysis_df = pd.DataFrame({ "Number of Unique Items":[total_unique],
                                        "Average Purchase Price":[average_price_df],
                                        "Total Number of Purchases":[total_purchases_df],
                                        "Total Revenue":[total_revenue_df]})
purchasing_analysis_df
# Out:
#    Average Purchase Price  Number of Unique Items  Total Number of Purchases  \
# 0                2.931192                     183                        780
#
#    Total Revenue
# 0        2286.33

# %%
# Gender Demographics:

#drop duplicate players names 
no_dup_players = purchase_data_df.drop_duplicates(['SN'], keep ='last')

#counts gender values 
gender_counts = no_dup_players['Gender'].value_counts().reset_index()

gender_counts
# Out:
#                        # of Players
# Gender
# Male                            465
# Female                          100
# Other / Non-Disclosed             8

# %%
# Percentage and Count of Male Players
male_data_df = purchase_data_df.loc[purchase_data_df["Gender"] == "Male"]
percent_male = round((len(male_data_df)/len(purchase_data_df)) * 100, 2)

percent_male
# Out:
# 81.15

# %%
# Percentage and Count of Female Players
female_data_df = purchase_data_df.loc[purchase_data_df["Gender"] == "Female"]
percent_female = round((len(female_data_df)/len(purchase_data_df)) * 100, 2)

percent_female
# Out:
# 17.44

# %%
# Percentage and Count of Other / Non-Disclosed
others_data_df = purchase_data_df.loc[purchase_data_df["Gender"] == "Other / Non-Disclosed"]
percent_others = round((len(others_data_df)/len(purchase_data_df)) * 100, 2)

percent_others
# Out:
# 1.41

# %%
gender_analysis_df = pd.DataFrame({ "Total Gender Demographics":[gender_counts],
                                    "Percent of Males":[percent_male],
                                    "Percent of Females":[percent_female],
                                    "Percent of Other/ Non-Disclosed":[percent_others]})
gender_analysis_df
# Out:
#    Percent of Females  Percent of Males  Percent of Other/ Non-Disclosed  \
# 0               17.44             81.15                             1.41
#
#                            Total Gender Demographics
# 0                         # of Players
# Gender    ...

# %%
gender_analysis_df = pd.DataFrame({ "Total Gender Demographics":[total_demo],
                                    "Percent of Males":[percent_male],
                                    "Percent of Females":[percent_female],
                                    "Percent of Other/ Non-Disclosed":[percent_others]})
gender_analysis_df

# %%
# Purchasing Analysis (Gender)--The below each broken by gender: 

# Purchase Count

gender_count_df = purchase_data_df.groupby("Gender")["Gender"].count()
gender_count_df.head()
# Out:
# Gender
# Female                   136
# Male                     633
# Other / Non-Disclosed     11
# Name: Gender, dtype: int64

# %%
# Average Purchase Price
gender_average_df = purchase_data_df.groupby("Gender")["Price"].mean()
round(gender_average_df, 2)
# Out:
# Gender
# Female                   2.82
# Male                     2.95
# Other / Non-Disclosed    3.25
# Name: Price, dtype: float64

# %%
# Total Purchase Value
gender_purchase_df = purchase_data_df.groupby("Gender")["Price"].sum()
round(gender_purchase_df, 2)
# Out:
# Gender
# Female                    382.91
# Male                     1867.68
# Other / Non-Disclosed      35.74
# Name: Price, dtype: float64

# %%
# Normalized Totals
normalized_gender_total_df = (round(gender_average_df, 2)/gender_count_df)
(normalized_gender_total_df)
# Out:
# Gender
# Female                   0.020735
# Male                     0.004660
# Other / Non-Disclosed    0.295455
# dtype: float64

# %%
purchasing_analysis_df = pd.DataFrame({ "Purchase Count":[gender_count_df],
                                        "Average Purchase Price":[round(gender_average_df, 2)],
                                        "Total Purchase Value":[round(gender_purchase_df, 2)],
                                        "Normalized Totals":[round(normalized_gender_total_df, 2)]})
purchasing_analysis_df
# Out:
#                               Average Purchase Price  \
# 0  Gender
# Female                   2.82
# Male     ...
#
#                                    Normalized Totals  \
# 0  Gender
# Female                   0.94
# Male     ...
#
#                                       Purchase Count  \
# 0  Gender
# Female                   100
# Male      ...
#
#                                 Total Purchase Value
# 0  Gender
# Female                    382.91
# Male  ...

# %%
# Age Demographics
# ----------------
bins = [0,10,15,20,25,30,35,40, 45]
age_demographics= ["<10", "10-14","15-19", "20-24", "25-29", "30-34", "35-39", ">=40"]
pd.cut(purchase_data_df["Age"], bins, labels=age_demographics)
# Out:
# 0      35-39
# 1      20-24
# 2      30-34
# 3      20-24
# 4      20-24
# 5      15-19
# 6      15-19
# 7      25-29
# 8      20-24
# 9      30-34
# 10     20-24
# 11     15-19
# 12     25-29
# 13     20-24
# 14     35-39
# 15     20-24
# 16     20-24
# 17     20-24
# 18     25-29
# 19     30-34
# 20     20-24
# 21     10-14
# 22     10-14
# 23     15-19
# 24     10-14
# 25     20-24
# 26     25-29
# 27     30-34
# 28     10-14
# 29     15-19
#        ...
# 750    20-24
# 751    25-29
# 752    10-14
# 753    15-19
# 754    30-34
# 755    20-24
# 756    20-24
# 757    30-34
# 758    15-19
# 759    15-19
# 760    25-29
# 761    25-29
# 762    35-39
# 763    25-29
# 764    20-24
# 765    10-14
# 766    20-24
# 767    15-19
# 768    20-24
# 769    20-24
# 770    20-24
# 771    20-24
# 772    10-14
# 773    20-24
# 774    20-24
# 775    20-24
# 776    10-14
# 777    15-19
# 778    15-19
# 779    20-24
# Name: Age, Length: 780, dtype: category
# ...

# %%
purchase_data_df["Age"] = pd.cut(purchase_data_df["Age"], bins, labels=age_demographics)
purchase_data_df
# Out:
#        Age                 Gender  Item ID  \
# 0    35-39                   Male      165
# 1    20-24                   Male      119
# 2    30-34                   Male      174
# 3    20-24                   Male       92
# 4    20-24                   Male       63
# 5    15-19                   Male       10
# 6    15-19                   Male      153
# 7    25-29                 Female      169
# 8    20-24                   Male      118
# 9    30-34                   Male       99
# 10   20-24                   Male       57
# 11   15-19                   Male       47
# 12   25-29                   Male       81
# 13   20-24                   Male       77
# 14   35-39                   Male       44
# 15   20-24                   Male       96
# 16   20-24                 Female      123
# 17   20-24                 Female       59
# 18   25-29                   Male       91
# 19   30-34                   Male      177
# 20   20-24                   Male       78
# ...

# %%
# Purchase Count by 
age_count_df = purchase_data_df.groupby("Age")["Price"].nunique()
age_count_df.head()
# Out:
# Age
# <10       27
# 10-14     63
# 15-19    103
# 20-24    129
# 25-29     58
# Name: Price, dtype: int64

# %%
# Average Purchase Price
age_average_df = purchase_data_df.groupby("Age")["Price"].mean()
round(age_average_df, 2)
# Out:
# Age
# <10      3.02
# 10-14    2.87
# 15-19    2.87
# 20-24    2.96
# 25-29    2.89
# 30-34    3.07
# 35-39    2.90
# >=40     2.88
# Name: Price, dtype: float64

# %%
# Total Purchase Value
total_purchase_df = purchase_data_df.groupby("Age")["Price"].sum()
round(total_purchase_df, 2)
# Out:
# Age
# <10       96.62
# 10-14    224.15
# 15-19    528.74
# 20-24    902.61
# 25-29    219.82
# 30-34    178.26
# 35-39    127.49
# >=40       8.64
# Name: Price, dtype: float64

# %%
# Normalized Totals
normalized_age_total_df = (round(age_average_df, 2))/total_purchase_df.count()
round(normalized_age_total_df, 2)
# Out:
# Age
# <10      0.38
# 10-14    0.36
# 15-19    0.36
# 20-24    0.37
# 25-29    0.36
# 30-34    0.38
# 35-39    0.36
# >=40     0.36
# Name: Price, dtype: float64

# %%
age_demographics_df = pd.DataFrame({ "Purchase Count": [age_count_df],
                                     "Average Purchase Price": [round(age_average_df, 2)],
                                     "Total Purchase Value": [round(total_purchase_df, 2)],
                                     "Normalized Totals": [round(normalized_age_total_df, 2)]})
age_demographics_df
# Out:
#                               Average Purchase Price  \
# 0  Age
# <10      3.02
# 10-14    2.87
# 15-19    2.87
# ...
#
#                                    Normalized Totals  \
# 0  Age
# <10      0.38
# 10-14    0.36
# 15-19    0.36
# ...
#
#                                       Purchase Count  \
# 0  Age
# <10       27
# 10-14     63
# 15-19    103
# 20-...
#
#                                 Total Purchase Value
# 0  Age
# <10       96.62
# 10-14    224.15
# 15-19    5...

# %%
# Top Spenders: Identify the the top 5 spenders in the game by total purchase value, then list (in a table):

# %%
# SN
purchase_amt_by_SN = pd.DataFrame(purchase_data_df .groupby('SN')['Price'].sum())
purchase_amt_by_SN
# Out:
#                  Price
# SN
# Adairialis76      2.46
# Aduephos78        6.70
# Aeduera68         5.80
# Aela49            2.46
# Aela59            1.27
# Aelalis34         5.06
# Aelin32           3.14
# Aeliriam77        6.72
# Aeliriarin93      2.04
# Aeliru63          8.98
# Aellyria80        4.32
# Aellyrialis39     3.15
# Aellysup38        3.61
# Aelollo59         1.55
# Aenarap34         1.65
# Aenasu69          3.27
# Aeral43           2.72
# Aeral85           4.25
# Aeral97           2.35
# Aeri84            6.60
# Aerillorin70      1.88
# Aerithllora36    10.45
# Aerithnucal56     3.18
# Aerithnuphos61    1.69
# Aerithriaphos45   2.38
# Aesty51           1.82
# Aesur96           4.66
# Aethe80           2.32
# Aethedru70        2.97
# Aidain51          6.84
# ...                ...
# Undjaskla97       4.57
# Undjasksya56      4.53
# Undotesta33       3.90
# Wailin72          2.04
# Whaestysu86       4.08
# Yadacal26         1.93
# Yadaisuir65       8.56
# ...

# %%
# Purchase Count
num_purchase_by_SN = pd.DataFrame(purchase_data_df .groupby('SN')['Price'].count())
num_purchase_by_SN
# Out:
#                  Price
# SN
# Adairialis76         1
# Aduephos78           3
# Aeduera68            3
# Aela49               1
# Aela59               1
# Aelalis34            2
# Aelin32              1
# Aeliriam77           2
# Aeliriarin93         1
# Aeliru63             2
# Aellyria80           1
# Aellyrialis39        1
# Aellysup38           1
# Aelollo59            1
# Aenarap34            1
# Aenasu69             1
# Aeral43              1
# Aeral85              1
# Aeral97              1
# Aeri84               2
# Aerillorin70         1
# Aerithllora36        3
# Aerithnucal56        2
# Aerithnuphos61       1
# Aerithriaphos45      1
# Aesty51              1
# Aesur96              1
# Aethe80              1
# Aethedru70           1
# Aidain51             2
# ...                ...
# Undjaskla97          1
# Undjasksya56         1
# Undotesta33          1
# Wailin72             1
# Whaestysu86          1
# Yadacal26            1
# Yadaisuir65          2
# ...

# %%
# Average Purchase Price
avg_purchase_by_SN = pd.DataFrame(purchase_data_df .groupby('SN')['Price'].mean())
avg_purchase_by_SN
# Out:
#                     Price
# SN
# Adairialis76     2.460000
# Aduephos78       2.233333
# Aeduera68        1.933333
# Aela49           2.460000
# Aela59           1.270000
# Aelalis34        2.530000
# Aelin32          3.140000
# Aeliriam77       3.360000
# Aeliriarin93     2.040000
# Aeliru63         4.490000
# Aellyria80       4.320000
# Aellyrialis39    3.150000
# Aellysup38       3.610000
# Aelollo59        1.550000
# Aenarap34        1.650000
# Aenasu69         3.270000
# Aeral43          2.720000
# Aeral85          4.250000
# Aeral97          2.350000
# Aeri84           3.300000
# Aerillorin70     1.880000
# Aerithllora36    3.483333
# Aerithnucal56    1.590000
# Aerithnuphos61   1.690000
# Aerithriaphos45  2.380000
# Aesty51          1.820000
# Aesur96          4.660000
# Aethe80          2.320000
# Aethedru70       2.970000
# Aidain51         3.420000
# ...                   ...
# Undjaskla97      4.570000
# Undjasksya56     4.530000
# Undotesta33      3.900000
# ...

# %%
# Total Purchase Value
total_purchase_by_SN = pd.DataFrame(purchase_data_df .groupby('SN')['Price'].sum())
total_purchase_by_SN
# Out:
#               Price
# SN
# Adairialis76   2.46
# Aduephos78     6.70
# Aeduera68      5.80
# Aela49         2.46
# Aela59         1.27

# %%
top_spender_df = pd.DataFrame({ "Purchase Amount": [purchase_amt_by_SN],
                                "Purchase Count": [num_purchase_by_SN],
                                "Average Purchase Price": [avg_purchase_by_SN ],
                                "Total Purchase Value": [total_purchase_by_SN],
                                })
top_spender_df.head()
# Out:
#                               Average Purchase Price  \
# 0                      Price
# SN                  ...
#
#                                      Purchase Amount  \
# 0                   Price
# SN
# ...
#
#                                       Purchase Count  \
# 0                   Price
# SN
# ...
#
#                                 Total Purchase Value
# 0                   Price
# SN
# ...
